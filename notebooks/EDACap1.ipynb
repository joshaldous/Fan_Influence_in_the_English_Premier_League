# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import random as rd
import os

# %%
default_df = pd.read_csv('/home/josh/Documents/dsi/caps/cap1/data/EPL.csv')
default_df.head()
# Out:
#          Date  HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  2000-08-19  Charlton       Man City     4     0   H     2     0   H
# 1  2000-08-19   Chelsea       West Ham     4     2   H     1     0   H
# 2  2000-08-19  Coventry  Middlesbrough     1     3   A     1     1   D
# 3  2000-08-19     Derby    Southampton     2     2   D     1     2   A
# 4  2000-08-19     Leeds        Everton     2     0   H     2     0   H
#
#             Referee  ...  HST  AST  HC  AC  HF  AF  HY  AY  HR  AR
# 0        Rob Harris  ...   14    4   6   6  13  12   1   2   0   0
# 1     Graham Barber  ...   10    5   7   7  19  14   1   2   0   0
# 2      Barry Knight  ...    3    9   8   4  15  21   5   3   1   0
# 3       Andy D'Urso  ...    4    6   5   8  11  13   1   1   0   0
# 4  Dermot Gallagher  ...    8    6   6   4  21  20   1   3   0   0
#
# [5 rows x 22 columns]

# %%
# for name in default_df.Referee:
refname = default_df.Referee.split(' ')
default_df['Ref_lastname'] = refname[-1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-af88f6c312e5> in <module>
#       1 # for name in default_df.Referee:
# ----> 2 refname = default_df.Referee.split(' ')
#       3 default_df['Ref_lastname'] = refname[-1]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
dirty = default_df.Referee
dirty
# Out:
# 0             Rob Harris
# 1          Graham Barber
# 2           Barry Knight
# 3            Andy D'Urso
# 4       Dermot Gallagher
#               ...
# 7565            A Taylor
# 7566          M Atkinson
# 7567            M Oliver
# 7568           S Attwell
# 7569          C Kavanagh
# Name: Referee, Length: 7570, dtype: object

# %%
for x in dirty:
    if x[-1] == ' ':
        x.strip()
    x.replace('.','')

# %%
dirty
# Out:
# 0             Rob Harris
# 1          Graham Barber
# 2           Barry Knight
# 3            Andy D'Urso
# 4       Dermot Gallagher
#               ...
# 7565            A Taylor
# 7566          M Atkinson
# 7567            M Oliver
# 7568           S Attwell
# 7569          C Kavanagh
# Name: Referee, Length: 7570, dtype: object

# %%
dirty_compare = default_df.loc[:,['Referee','Ref_lastname']]

# %%
dirty_compare
# Out:
#                Referee Ref_lastname
# 0           Rob Harris     Kavanagh
# 1        Graham Barber     Kavanagh
# 2         Barry Knight     Kavanagh
# 3          Andy D'Urso     Kavanagh
# 4     Dermot Gallagher     Kavanagh
# ...                ...          ...
# 7565          A Taylor     Kavanagh
# 7566        M Atkinson     Kavanagh
# 7567          M Oliver     Kavanagh
# 7568         S Attwell     Kavanagh
# 7569        C Kavanagh     Kavanagh
#
# [7570 rows x 2 columns]

# %%
default_df.drop('Ref_lastname',axis=1,inplace=True)

# %%
default_df.Referee.unique()
# Out:
# array(['Rob Harris', 'Graham Barber', 'Barry Knight', "Andy D'Urso",
#        'Dermot Gallagher', 'Mike Riley', 'Paul Durkin', 'Steve Dunn',
#        'Alan Wiley', 'Steve Lodge', 'Graham Poll', 'Mark Halsey',
#        'Jeff Winter', 'Peter Jones', 'Andy Hall', 'David Ellaray',
#        'F Taylor', 'Rob Styles', 'Steve Bennett', 'Ian Harris',
#        'Paul Taylor', 'Neale Barry', 'Mike Dean', 'Roy Burton',
#        'Matt Messias', 'Clive Wilkes', "Andy D'Urso ", 'Mark Halsey ',
#        'Steve Bennett ', 'N. S. Barry', 'P. A. Durkin', 'C. R. Wilkes ',
#        'R. Styles', 'J. T. Winter', 'G. P. Barber', 'G. Poll',
#        'D. J. Gallagher', "A. P. D'Urso ", 'P. Jones ', 'D. R. Elleray ',
#        'J. T. Winter ', 'S. W. Dunn ', 'E. K. Wolstenholme ',
#        'A. G. Wiley ', 'B. Knight ', 'S. G. Bennett', 'U. D. Rennie',
#        'M. L Dean', 'P. A. Durkin ', 'G. P. Barber ', 'M. A. Riley ',
#        'G. Poll ', 'C. R. Wilkes', 'B. Knight', "A. P. D'Urso",
# ...

# %%
for x in default_df.Referee:
    if x[-1] == ' ':
        x.strip()

# %%
default_df.Referee.unique()
# Out:
# array(['Rob Harris', 'Graham Barber', 'Barry Knight', "Andy D'Urso",
#        'Dermot Gallagher', 'Mike Riley', 'Paul Durkin', 'Steve Dunn',
#        'Alan Wiley', 'Steve Lodge', 'Graham Poll', 'Mark Halsey',
#        'Jeff Winter', 'Peter Jones', 'Andy Hall', 'David Ellaray',
#        'F Taylor', 'Rob Styles', 'Steve Bennett', 'Ian Harris',
#        'Paul Taylor', 'Neale Barry', 'Mike Dean', 'Roy Burton',
#        'Matt Messias', 'Clive Wilkes', "Andy D'Urso ", 'Mark Halsey ',
#        'Steve Bennett ', 'N. S. Barry', 'P. A. Durkin', 'C. R. Wilkes ',
#        'R. Styles', 'J. T. Winter', 'G. P. Barber', 'G. Poll',
#        'D. J. Gallagher', "A. P. D'Urso ", 'P. Jones ', 'D. R. Elleray ',
#        'J. T. Winter ', 'S. W. Dunn ', 'E. K. Wolstenholme ',
#        'A. G. Wiley ', 'B. Knight ', 'S. G. Bennett', 'U. D. Rennie',
#        'M. L Dean', 'P. A. Durkin ', 'G. P. Barber ', 'M. A. Riley ',
#        'G. Poll ', 'C. R. Wilkes', 'B. Knight', "A. P. D'Urso",
# ...

# %%
for x in default_df.Referee:
    np.where("D'Urso" in x,x.replace(x,"Andy D'Urso",inplace=True),x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-60c9a62b634a> in <module>
#       1 for x in default_df.Referee:
# ----> 2     np.where("D'Urso" in x,x.replace(x,"Andy D'Urso",inplace=True),x)
#
# TypeError: replace() takes no keyword arguments

# %%
default_df.Referee.unique()
# Out:
# array(['Rob Harris', 'Graham Barber', 'Barry Knight', "Andy D'Urso",
#        'Dermot Gallagher', 'Mike Riley', 'Paul Durkin', 'Steve Dunn',
#        'Alan Wiley', 'Steve Lodge', 'Graham Poll', 'Mark Halsey',
#        'Jeff Winter', 'Peter Jones', 'Andy Hall', 'David Ellaray',
#        'F Taylor', 'Rob Styles', 'Steve Bennett', 'Ian Harris',
#        'Paul Taylor', 'Neale Barry', 'Mike Dean', 'Roy Burton',
#        'Matt Messias', 'Clive Wilkes', "Andy D'Urso ", 'Mark Halsey ',
#        'Steve Bennett ', 'N. S. Barry', 'P. A. Durkin', 'C. R. Wilkes ',
#        'R. Styles', 'J. T. Winter', 'G. P. Barber', 'G. Poll',
#        'D. J. Gallagher', "A. P. D'Urso ", 'P. Jones ', 'D. R. Elleray ',
#        'J. T. Winter ', 'S. W. Dunn ', 'E. K. Wolstenholme ',
#        'A. G. Wiley ', 'B. Knight ', 'S. G. Bennett', 'U. D. Rennie',
#        'M. L Dean', 'P. A. Durkin ', 'G. P. Barber ', 'M. A. Riley ',
#        'G. Poll ', 'C. R. Wilkes', 'B. Knight', "A. P. D'Urso",
# ...

# %%
df = default_df.copy()

# %%
rname = df.Referee.str.split(' ')

# %%
lastn = [x[-1] for x in rname]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-361-798665d37456> in <module>
# ----> 1 lastn = [x[-1] for x in rname]
#
# <ipython-input-361-798665d37456> in <listcomp>(.0)
# ----> 1 lastn = [x[-1] for x in rname]
#
# TypeError: 'float' object is not subscriptable

# %%
df['Reflast'] = lastn

# %%
df.Reflast
# Out:
# 0          Harris
# 1          Barber
# 2          Knight
# 3          D'Urso
# 4       Gallagher
#           ...
# 7565       Taylor
# 7566     Atkinson
# 7567       Oliver
# 7568      Attwell
# 7569     Kavanagh
# Name: Reflast, Length: 7570, dtype: object

# %%
ref_dict['England'] = 'Darren England'

# %%
ref_dict
# Out:
# {'Harris': 'Rob Harris',
#  'Barber': 'Graham Barber',
#  'Knight': 'Barry Knight',
#  "D'Urso": "Andy D'Urso",
#  'Gallagher': 'Dermot Gallagher',
#  'Riley': 'Mike Riley',
#  'Durkin': 'Paul Durkin',
#  'Dunn': 'Steve Dunn',
#  'Wiley': 'Alan Wiley',
#  'Lodge': 'Steve Lodge',
#  'Poll': 'Graham Poll',
#  'Halsey': 'Mark Halsey',
#  'Winter': 'Jeff Winter',
#  'Jones': 'check',
#  'Hall': 'Andy Hall',
#  'Ellaray': 'David Elleray',
#  'Taylor': 'check',
#  'Styles': 'Rob Styles',
#  'Bennett': 'Steve Bennett',
#  'Barry': 'Neale Barry',
#  'Dean': 'Mike Dean',
#  'Burton': 'Roy Burton',
#  'Messias': 'Matt Messias',
#  'Wilkes': 'Clive Wilkes',
#  '': 'check',
#  'Rennie': 'Uriah Rennie',
#  'Pugh': 'David Pugh',
#  'Wolstenholme': 'Eddie Wolstenholme',
#  'Elleray': 'David Elleray',
#  'Dowd': 'Phil Dowd',
#  'Foy': 'Chris Foy',
#  'G.': 'check',
#  'R.': 'check',
#  'T.': 'check',
#  'K.': 'check',
#  'W.': 'check',
#  'B.': 'check',
#  'A.': 'check',
#  'D.': 'check',
# ...

# %%
for x in df.Reflast:
    print(xf taylo)
#     df['ref_name'] = ref_dict[x]
# Out:
# Harris
# Barber
# Knight
# D'Urso
# Gallagher
# Riley
# Durkin
# Dunn
# Wiley
# Lodge
# Poll
# Halsey
# Winter
# Jones
# Hall
# Ellaray
# Gallagher
# Taylor
# Styles
# Lodge
# Bennett
# Riley
# Poll
# D'Urso
# Barber
# Ellaray
# Winter
# Gallagher
# Durkin
# Poll
# Harris
# Jones
# Knight
# Halsey
# Riley
# Wiley
# Styles
# Taylor
# Barry
# Wiley
# Durkin
# D'Urso
# Dean
# Barber
# Barry
# Bennett
# Poll
# Jones
# Dunn
# Dean
# Styles
# Winter
# Gallagher
# Halsey
# Knight
# Taylor
# Barber
# Lodge
# Ellaray
# Dunn
# Barry
# Knight
# Durkin
# Riley
# Jones
# Halsey
# D'Urso
# Bennett
# Wiley
# Ellaray
# Styles
# Winter
# Barry
# Taylor
# Poll
# Dean
# Barber
# Gallagher
# Lodge
# Harris
# Jones
# Ellaray
# Barry
# Dean
# Durkin
# Knight
# Winter
# Bennett
# Dunn
# Taylor
# Riley
# Lodge
# D'Urso
# Winter
# Halsey
# Dean
# Gallagher
# Styles
# Wiley
# Styles
# Gallagher
# Dunn
# Barry
# Poll
# D'Urso
# Wiley
# Riley
# Lodge
# Durkin
# Barry
# Poll
# Ellaray
# Halsey
# D'Urso
# Wiley
# ...

# %%
df['ref_name'] = [ref_dict[x] for x in df.Reflast]
df.ref_name
# Out:
# 0             Rob Harris
# 1          Graham Barber
# 2           Barry Knight
# 3            Andy D'Urso
# 4       Dermot Gallagher
#               ...
# 7565               check
# 7566     Martin Atkinson
# 7567      Michael Oliver
# 7568      Stuart Attwell
# 7569      Chris Kavanagh
# Name: ref_name, Length: 7570, dtype: object

# %%
df.Referee.str.strip(' ')
# Out:
# 0             Rob Harris
# 1          Graham Barber
# 2           Barry Knight
# 3            Andy D'Urso
# 4       Dermot Gallagher
#               ...
# 7566          M Atkinson
# 7567            M Oliver
# 7568           S Attwell
# 7569          C Kavanagh
# 12                   NaN
# Name: Referee, Length: 7571, dtype: object

# %%
namecheck = df.loc[:,['Referee','Reflast','ref_name']]

# %%
namecheck[df.ref_name == 'check']
# Out:
# Empty DataFrame
# Columns: [Referee, Reflast, ref_name]
# Index: []

# %%
mj = 'Mike Jones'
at = 'Anthony Taylor'
ad = 'Andy D\'Urso'
sd = 'Steve Dunn'
bk = 'Barry Knight'
rm = 'Robby Madley'
am = 'Andy Madley'
ew = 'Eddie Wolstenholme'
gp = 'Graham Poll'
gb = 'Graham Barber'
rs = 'Rob Styles'
de = 'David Elleray'
dp = 'David Pugh'
pd = 'Paul Durkin'
dg = 'Dermot Gallagher'
sb = 'Steve Bennett'
md = 'Mike Dean'
phil = 'Phil Dowd'
cf = 'Chris Foy'
cw = 'Clive Wilkes'
mm = 'Matt Messias'
mh = 'Mark Halsey'
nb = 'Neale Barry'
aw = 'Alan Wiley'
jw = 'Jeff Winter'

# %%
df.at[6820,'ref_name'] = mj

# %%
df.iloc[7380:7420,:]
# Out:
#             Date          HomeTeam          AwayTeam  FTHG  FTAG FTR  HTHG  \
# 7380  2019-12-14         Liverpool           Watford   2.0   0.0   H   1.0
# 7381  2019-12-14           Burnley         Newcastle   1.0   0.0   H   0.0
# 7382  2019-12-14           Chelsea       Bournemouth   0.0   1.0   A   0.0
# 7383  2019-12-14         Leicester           Norwich   1.0   1.0   D   1.0
# 7384  2019-12-14  Sheffield United       Aston Villa   2.0   0.0   H   0.0
# 7385  2019-12-14       Southampton          West Ham   0.0   1.0   A   0.0
# 7386  2019-12-15        Man United           Everton   1.0   1.0   D   0.0
# 7387  2019-12-15            Wolves         Tottenham   1.0   2.0   A   0.0
# 7388  2019-12-15           Arsenal          Man City   0.0   3.0   A   0.0
# 7389  2019-12-16    Crystal Palace          Brighton   1.0   1.0   D   0.0
# 7390  2019-12-21           Everton           Arsenal   0.0   0.0   D   0.0
# ...

# %%
epl2000to2020_cleaned = df.copy()

# %%
epl2000to2020_cleaned.head()
# Out:
#          Date  HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  2000-08-19  Charlton       Man City   4.0   0.0   H   2.0   0.0   H
# 1  2000-08-19   Chelsea       West Ham   4.0   2.0   H   1.0   0.0   H
# 2  2000-08-19  Coventry  Middlesbrough   1.0   3.0   A   1.0   1.0   D
# 3  2000-08-19     Derby    Southampton   2.0   2.0   D   1.0   2.0   A
# 4  2000-08-19     Leeds        Everton   2.0   0.0   H   2.0   0.0   H
#
#             Referee  ...   HC   AC    HF    AF   HY   AY   HR   AR    Reflast  \
# 0        Rob Harris  ...  6.0  6.0  13.0  12.0  1.0  2.0  0.0  0.0     Harris
# 1     Graham Barber  ...  7.0  7.0  19.0  14.0  1.0  2.0  0.0  0.0     Barber
# 2      Barry Knight  ...  8.0  4.0  15.0  21.0  5.0  3.0  1.0  0.0     Knight
# 3       Andy D'Urso  ...  5.0  8.0  11.0  13.0  1.0  1.0  0.0  0.0     D'Urso
# 4  Dermot Gallagher  ...  6.0  4.0  21.0  20.0  1.0  3.0  0.0  0.0  Gallagher
#
#            ref_name
# 0        Rob Harris
# 1     Graham Barber
# ...

# %%
epl2000to2020_cleaned.drop('Referee',axis=1,inplace=True)

# %%
epl2000to2020_cleaned.drop('Reflast',axis=1,inplace=True)

# %%
epl2000to2020_cleaned.head()
# Out:
#          Date  HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR    HS  \
# 0  2000-08-19  Charlton       Man City   4.0   0.0   H   2.0   0.0   H  17.0
# 1  2000-08-19   Chelsea       West Ham   4.0   2.0   H   1.0   0.0   H  17.0
# 2  2000-08-19  Coventry  Middlesbrough   1.0   3.0   A   1.0   1.0   D   6.0
# 3  2000-08-19     Derby    Southampton   2.0   2.0   D   1.0   2.0   A   6.0
# 4  2000-08-19     Leeds        Everton   2.0   0.0   H   2.0   0.0   H  17.0
#
#    ...  AST   HC   AC    HF    AF   HY   AY   HR   AR          ref_name
# 0  ...  4.0  6.0  6.0  13.0  12.0  1.0  2.0  0.0  0.0        Rob Harris
# 1  ...  5.0  7.0  7.0  19.0  14.0  1.0  2.0  0.0  0.0     Graham Barber
# 2  ...  9.0  8.0  4.0  15.0  21.0  5.0  3.0  1.0  0.0      Barry Knight
# 3  ...  6.0  5.0  8.0  11.0  13.0  1.0  1.0  0.0  0.0       Andy D'Urso
# 4  ...  6.0  6.0  4.0  21.0  20.0  1.0  3.0  0.0  0.0  Dermot Gallagher
#
# [5 rows x 22 columns]

# %%
epl2000to2020_cleaned.columns
# Out:
# Index(['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG',
#        'HTR', 'HS', 'AS', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY',
#        'HR', 'AR', 'ref_name'],
#       dtype='object')

# %%
epl2000to2020_cleaned.to_csv('epl_cleaned.csv')
